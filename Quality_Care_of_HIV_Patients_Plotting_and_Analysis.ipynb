# %% [markdown]
# <a href="https://colab.research.google.com/github/ArmandFS/hiv-quality-of-care-vis-update/blob/main/Quality_Care_of_HIV_Patients_Plotting_and_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Exploring Quality of Care Data for HIV Clients, Plotting, and Analysis
#
# ### Import Libraries for Analysis
# ##### Here in this cell, we are going to import a bunch of libraries to help us analyze this data. Numpy as is used for linear algebra and mathematical calculations, pandas is used for data processing and reading csv data, matplotlib will be used for plotting our data. The os library is used for joining different data from different files and managing the main directory
#
# ##### Additional Libraries will be added down the line for visualization and configuration

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ### Loading the data
# ##### Let's load our data into a pandas dataframe using the read_excel function. The data describe function is used to get a bit of insight of the numeric data in the datatable.

# %%
excel_data = pd.read_excel('QualityOfCare.xlsx')

# %%
data = pd.DataFrame(excel_data)
stats_table = data.describe()

styled_table = stats_table.style\
    .set_caption('Quality Care of HIV Patients Initial Dataset')\
    .set_table_styles([
        {'selector': 'caption',
         'props': [
             ('font-size', '18px'),
             ('font-weight', 'bold'),
             ('text-align', 'center')
         ]},
        {'selector': 'table',
         'props': [
             ('border-collapse', 'collapse')
         ]},
        {'selector': 'th, td',
         'props': [
             ('border', '1px solid black'),
             ('padding', '8px')
         ]}
    ])
styled_table = styled_table.background_gradient(cmap='Blues', subset=stats_table.columns[0:])

styled_table
# Out:
# <style type="text/css">
# #T_138a6 caption {
#   font-size: 18px;
#   font-weight: bold;
#   text-align: center;
# }
# #T_138a6 table {
#   border-collapse: collapse;
# }
# #T_138a6 th {
#   border: 1px solid black;
#   padding: 8px;
# }
# #T_138a6  td {
#   border: 1px solid black;
#   padding: 8px;
# }
# #T_138a6_row0_col0, #T_138a6_row2_col7 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_138a6_row0_col1 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_138a6_row0_col2, #T_138a6_row0_col3, #T_138a6_row0_col5, #T_138a6_row7_col0, #T_138a6_row7_col1, #T_138a6_row7_col4, #T_138a6_row7_col6, #T_138a6_row7_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_138a6_row0_col4, #T_138a6_row0_col7 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_138a6_row0_col6 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_138a6_row1_col0, #T_138a6_row1_col2, #T_138a6_row1_col4, #T_138a6_row1_col5, #T_138a6_row1_col6, #T_138a6_row1_col7, #T_138a6_row2_col2, #T_138a6_row2_col3, #T_138a6_row2_col5, #T_138a6_row3_col0, #T_138a6_row3_col1, #T_138a6_row3_col2, #T_138a6_row3_col3, #T_138a6_row3_col4, #T_138a6_row3_col5, #T_138a6_row3_col6, #T_138a6_row3_col7, #T_138a6_row4_col0, #T_138a6_row4_col1, #T_138a6_row4_col2, #T_138a6_row4_col4, #T_138a6_row4_col5, #T_138a6_row4_col6, #T_138a6_row4_col7, #T_138a6_row5_col0, #T_138a6_row5_col1, #T_138a6_row5_col2, #T_138a6_row5_col4, #T_138a6_row5_col5, #T_138a6_row5_col7, #T_138a6_row6_col0, #T_138a6_row6_col2, #T_138a6_row6_col4, #T_138a6_row6_col5, #T_138a6_row6_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_138a6_row1_col1, #T_138a6_row2_col0, #T_138a6_row5_col6, #T_138a6_row6_col6, #T_138a6_row7_col2 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_138a6_row1_col3, #T_138a6_row2_col4, #T_138a6_row2_col6, #T_138a6_row4_col3, #T_138a6_row5_col3, #T_138a6_row6_col1, #T_138a6_row6_col3 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_138a6_row2_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_138a6_row7_col3 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_138a6_row7_col5 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# </style>
# <table id="T_138a6" class="dataframe">
#   <caption>Quality Care of HIV Patients Initial Dataset</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_138a6_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_138a6_level0_col1" class="col_heading level0 col1" >AgeInMonths</th>
#       <th id="T_138a6_level0_col2" class="col_heading level0 col2" >WeightAtStart</th>
#       <th id="T_138a6_level0_col3" class="col_heading level0 col3" >HeightAtStart</th>
#       <th id="T_138a6_level0_col4" class="col_heading level0 col4" >Cd4AtStart</th>
#       <th id="T_138a6_level0_col5" class="col_heading level0 col5" >WeightAtLastVisit</th>
#       <th id="T_138a6_level0_col6" class="col_heading level0 col6" >HeightAtLastVisit</th>
#       <th id="T_138a6_level0_col7" class="col_heading level0 col7" >MostRecentCd4Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_138a6_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_138a6_row0_col0" class="data row0 col0" >26569.000000</td>
#       <td id="T_138a6_row0_col1" class="data row0 col1" >642.000000</td>
#       <td id="T_138a6_row0_col2" class="data row0 col2" >25065.000000</td>
#       <td id="T_138a6_row0_col3" class="data row0 col3" >15357.000000</td>
#       <td id="T_138a6_row0_col4" class="data row0 col4" >21906.000000</td>
#       <td id="T_138a6_row0_col5" class="data row0 col5" >24444.000000</td>
#       <td id="T_138a6_row0_col6" class="data row0 col6" >15231.000000</td>
#       <td id="T_138a6_row0_col7" class="data row0 col7" >20106.000000</td>
#     </tr>
#     <tr>
#       <th id="T_138a6_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_138a6_row1_col0" class="data row1 col0" >109.559047</td>
#       <td id="T_138a6_row1_col1" class="data row1 col1" >14.890966</td>
#       <td id="T_138a6_row1_col2" class="data row1 col2" >54.920870</td>
#       <td id="T_138a6_row1_col3" class="data row1 col3" >142.788071</td>
#       <td id="T_138a6_row1_col4" class="data row1 col4" >451.511158</td>
#       <td id="T_138a6_row1_col5" class="data row1 col5" >60.014575</td>
#       <td id="T_138a6_row1_col6" class="data row1 col6" >144.670872</td>
#       <td id="T_138a6_row1_col7" class="data row1 col7" >654.213839</td>
#     </tr>
#     <tr>
#       <th id="T_138a6_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_138a6_row2_col0" class="data row2 col0" >12159.486892</td>
#       <td id="T_138a6_row2_col1" class="data row2 col1" >80.235363</td>
#       <td id="T_138a6_row2_col2" class="data row2 col2" >17.123884</td>
#       <td id="T_138a6_row2_col3" class="data row2 col3" >51.772227</td>
#       <td id="T_138a6_row2_col4" class="data row2 col4" >6625.037637</td>
#       <td id="T_138a6_row2_col5" class="data row2 col5" >30.309822</td>
#       <td id="T_138a6_row2_col6" class="data row2 col6" >335.184395</td>
#       <td id="T_138a6_row2_col7" class="data row2 col7" >7467.950481</td>
#     </tr>
#     <tr>
#       <th id="T_138a6_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_138a6_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_138a6_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_138a6_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_138a6_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_138a6_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_138a6_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_138a6_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_138a6_row3_col7" class="data row3 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_138a6_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_138a6_row4_col0" class="data row4 col0" >27.000000</td>
#       <td id="T_138a6_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_138a6_row4_col2" class="data row4 col2" >47.000000</td>
#       <td id="T_138a6_row4_col3" class="data row4 col3" >150.000000</td>
#       <td id="T_138a6_row4_col4" class="data row4 col4" >139.000000</td>
#       <td id="T_138a6_row4_col5" class="data row4 col5" >50.000000</td>
#       <td id="T_138a6_row4_col6" class="data row4 col6" >150.000000</td>
#       <td id="T_138a6_row4_col7" class="data row4 col7" >229.000000</td>
#     </tr>
#     <tr>
#       <th id="T_138a6_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_138a6_row5_col0" class="data row5 col0" >34.000000</td>
#       <td id="T_138a6_row5_col1" class="data row5 col1" >2.000000</td>
#       <td id="T_138a6_row5_col2" class="data row5 col2" >55.000000</td>
#       <td id="T_138a6_row5_col3" class="data row5 col3" >160.000000</td>
#       <td id="T_138a6_row5_col4" class="data row5 col4" >267.000000</td>
#       <td id="T_138a6_row5_col5" class="data row5 col5" >60.000000</td>
#       <td id="T_138a6_row5_col6" class="data row5 col6" >160.000000</td>
#       <td id="T_138a6_row5_col7" class="data row5 col7" >396.000000</td>
#     </tr>
#     <tr>
#       <th id="T_138a6_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_138a6_row6_col0" class="data row6 col0" >42.000000</td>
#       <td id="T_138a6_row6_col1" class="data row6 col1" >18.000000</td>
#       <td id="T_138a6_row6_col2" class="data row6 col2" >65.000000</td>
#       <td id="T_138a6_row6_col3" class="data row6 col3" >166.000000</td>
#       <td id="T_138a6_row6_col4" class="data row6 col4" >434.000000</td>
#       <td id="T_138a6_row6_col5" class="data row6 col5" >69.000000</td>
#       <td id="T_138a6_row6_col6" class="data row6 col6" >166.000000</td>
#       <td id="T_138a6_row6_col7" class="data row6 col7" >600.000000</td>
#     </tr>
#     <tr>
#       <th id="T_138a6_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_138a6_row7_col0" class="data row7 col0" >1982014.000000</td>
#       <td id="T_138a6_row7_col1" class="data row7 col1" >1987.000000</td>
#       <td id=

# %% [markdown]
# ##### Let's look at the different columns of the datatable. The data has about 46 different columns

# %%
print(f'The dataset has {len(data.columns)} columns')
print("---------------------------------------------")
data.columns
# Out:
# The dataset has 46 columns
# ---------------------------------------------
# Index(['Health facility level', 'FacilityType', 'FundingSources',
#        'DateOfBirth', 'Age', 'AgeInMonths', 'Sex', 'MaritalStatus',
#        'EducationLevel', 'Occupation', 'DateOfConfirmedHIV',
#        'DateOfEnrollment', 'CareEntryPoint', 'DateArtStarted',
#        'RegimenAtStart', 'WeightAtStart', 'HeightUnit', 'HeightAtStart',
#        'FunctionalStatusAtStart', 'ClinicalStageAtStart', 'Cd4Unit',
#        'Cd4AtStart', 'AdherenceCouncelingCompleted', 'InitialTbScreeningDone',
#        'ArtSubstitution', 'ArtSwitch', 'ArtInterruption', 'PatientDead',
#        'ClinicalStageAtLastVisit', 'TbStatusAtLAstVisit', 'WeightAtLastVisit',
#        'HeightAtLastVisit', 'OpportunisticInfectionPresentAtLastVisit',
#        'AnySideEffects', 'WasPatientReceivingArv', 'ArvAdherenceLatestLevel',
#        'MostRecentCd4Count', 'ViralLoadDone', 'PregnancyStatus',
#        'ArtInterruptionType', 'ArtInterruptionDate', 'ArtInterruptionReason',
#        'OpportunisticInfectionAtLastVisit',
#        'OpportunisticInfectionAtLastVisitOthers', 'CurrentRegimen',
#        'ViralLoad'],
#       dtype='object')

# %% [markdown]
# ##### We can also list the columns with their corresponding data types

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27288 entries, 0 to 27287
# Data columns (total 46 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Health facility level                     27288 non-null  object
#  1   FacilityType                              27288 non-null  object
#  2   FundingSources                            27196 non-null  object
#  3   DateOfBirth                               24493 non-null  object
#  4   Age                                       26569 non-null  float64
#  5   AgeInMonths                               642 non-null    float64
#  6   Sex                                       27288 non-null  object
#  7   MaritalStatus                             25547 non-null  object
#  8   EducationLevel                            24638 non-null  object
#  9   Occupation                                24610 non-null  object
#  10  DateOfConfirmedHIV                        26574 non-null  object
#  11  DateOfEnrollment                          26696 non-null  object
#  12  CareEntryPoint                            25434 non-null  object
#  13  DateArtStarted                            27288 non-null  object
#  14  RegimenAtStart                            26622 non-null  object
#  15  WeightAtStart                             25065 non-null  float64
#  16  HeightUnit                                17845 non-null  object
#  17  HeightAtStart                             15357 non-null  float64
#  18  FunctionalStatusAtStart                   26518 non-null  object
#  19  ClinicalStageAtStart                      26130 non-null  object
#  20  Cd4Unit                                   23323 non-null  object
#  21  Cd4AtStart                                21906 non-null  float64
#  22  AdherenceCouncelingCompleted              26475 non-null  object
#  23  InitialTbScreeningDone                    26484 non-null  object
#  24  ArtSubstitution                           26678 non-null  object
#  25  ArtSwitch                                 26023 non-null  object
#  26  ArtInterruption                           26063 non-null  object
#  27  PatientDead                               26761 non-null  object
#  28  ClinicalStageAtLastVisit                  26086 non-null  object
#  29  TbStatusAtLAstVisit                       25362 non-null  object
#  30  WeightAtLastVisit                         24444 non-null  float64
#  31  HeightAtLastVisit                         15231 non-null  float64
#  32  OpportunisticInfectionPresentAtLastVisit  26492 non-null  object
#  33  AnySideEffects                            26098 non-null  object
#  34  WasPatientReceivingArv                    26346 non-null  object
#  35  ArvAdherenceLatestLevel                   25991 non-null  object
#  36  MostRecentCd4Count                        20106 non-null  float64
#  37  ViralLoadDone                             24247 non-null  object
#  38  PregnancyStatus                           16581 non-null  object
#  39  ArtInterruptionType                       2367 non-null   object
#  40  ArtInterruptionDate                       2310 non-null   object
#  41  ArtInterruptionReason                     1757 non-null   object
#  42  OpportunisticInfectionAtLastVisit         2874 non-null   object
#  43  OpportunisticInfectionAtLastVisitOthers   995 non-null    object
#  44  CurrentRegimen                            23028 non-null  object
#  45  ViralLoad                                 13763 non-null  object
# dtypes: float64(8), object(38)
# memory usage: 9.6+ MB

# %% [markdown]
# ### Reviewing the Gender Demographic Data
# ##### We can see based off the data that we have a few demographics that we'd want to plot and compare, such as gender representations. We can plot it based off the sex column to find out how the different sexes are represented in the dataset. The pandas unique function will get the data from the sex column
#
# ##### We can then plot a bar chart, showing a comparison of male and females

# %%
data['Sex'].unique()
male_count = data['Sex'].value_counts()['Male']
female_count = data['Sex'].value_counts()['Female']
#we then print the total amount of males and females

print(f"Number of Males: {male_count}")
print(f"Number of Females: {female_count}")
print("-----------------------------------")

sexes = list(data['Sex'].unique())
values = list(data['Sex'].value_counts())
fig = go.Figure(data=[go.Bar(x=sexes, y=values, marker_color=['red', 'blue'])])
fig.update_layout(
    title="HIV Clients Receiving Treatment: Gender Chart",
    xaxis_title="Sex",
    yaxis_title="No. of clients",
    width=400,
    height=500
)
fig.show()
# Out:
# Number of Males: 8808
# Number of Females: 18480
# -----------------------------------
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b191fc0d-987d-4c25-aa26-4927fbcb2de7" class="plotly-graph-div" style="height:500px; width:400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b191fc0d-987d-4c25-aa26-4927fbcb2de7")) {                    Plotly.newPlot(                        "b191fc0d-987d-4c25-aa26-4927fbcb2de7",                        [{"marker":{"color":["red","blue"]},"x":["Female","Male"],"y":[18480,8808],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d ...

# %% [markdown]
# ### Age Calculation and Comparison
# ##### Let's look at the age of the clients. The dataset already has age information but we can calculate the age from the date of birth to get better accuracy. The dataset has age and also date of birth so, we will recalculate the age from the date of birth. To do this, we will define a function that will help us calculate the age. To calculate this, we can use the datetime library.

# %%
from datetime import date
from datetime import datetime

def age(birthdate):
      today = datetime.today()
      age = today.year - birthdate.year - ((today.month, today.day) < (birthdate.month, birthdate.day))
      return age

for ind, row in data.iterrows():
    date = pd.to_datetime(row['DateOfBirth'], errors='coerce', infer_datetime_format=True)
    data.loc[ind, ['CalculatedAge']] = age(date)

data.head()
# Out:
#        Health facility level FacilityType  \
# 0          Tertiary hospital       Public
# 1  Secondary health facility       Public
# 2  Secondary health facility       Public
# 3          Tertiary hospital       Public
# 4  Secondary health facility  Faith Based
#
#                                       FundingSources          DateOfBirth  \
# 0                     ,Non-Governmental Organisation           28/11/2000
# 1                                  ,State Government  1986-05-06 00:00:00
# 2  ,Federal Government,Non-Governmental Organisation  1955-12-04 00:00:00
# 3                     ,Non-Governmental Organisation            15/4/1963
# 4                     ,Non-Governmental Organisation  1985-12-03 00:00:00
#
#     Age  AgeInMonths     Sex MaritalStatus EducationLevel     Occupation  ...  \
# 0  18.0          NaN  Female        Single       Tertiary        Student  ...
# 1  28.0          NaN  Female       Married        Primary     Unemployed  ...
# 2  50.0          NaN    Male       Married        Primary  Civil servant  ...
# 3  51.0          NaN  Female       Married        Missing  Self employed  ...
# 4  30.0          NaN  Female        Single      Secondary  Self employed  ...
#
#   ViralLoadDone PregnancyStatus ArtInterruptionType ArtInterruptionDate  \
# 0            No   Non-oregnancy                 NaN                 NaN
# 1           Yes   Non-oregnancy                 NaN                 NaN
# 2           Yes             NaN                 NaN                 NaN
# 3           Yes   Non-oregnancy                 NaN                 NaN
# 4            No   Non-oregnancy                 NaN                 NaN
#
#   ArtInterruptionReason  OpportunisticInfectionAtLastVisit  \
# 0                   NaN                                NaN
# 1                   NaN                                NaN
# 2                   NaN                                NaN
# 3                   NaN                                NaN
# 4                   NaN                                NaN
#
#   OpportunisticInfectionAtLastVisitOthers      CurrentRegimen  ViralLoad  \
# 0                                     NaN  First-line Regimen        NaN
# 1                                     NaN  First-line Regimen         20
# 2                                     NaN  First-line Regimen        <20
# 3                                     NaN  First-line Regimen  9031co/ml
# 4                                     NaN  First-line Regimen        NaN
#
#   CalculatedAge
# 0          22.0
# 1          37.0
# 2          67.0
# 3          60.0
# 4          37.0
#
# [5 rows x 47 columns]

# %% [markdown]
# ##### Now we can plot the calculated ages  of the dataset in a histogram. Plotly is used for better visualization

# %%
# Convert the Pandas plot to a Plotly figure
fig = px.histogram(data, x="CalculatedAge", color="Sex")
fig.update_layout(
    title="Age Distribution by Sex",
    xaxis_title="Calculated Age",
    yaxis_title="Count",
    width=1000,  
    height=500 
)
# Display the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="2577db7f-7c6d-4983-85ab-b773b730369d" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2577db7f-7c6d-4983-85ab-b773b730369d")) {                    Plotly.newPlot(                        "2577db7f-7c6d-4983-85ab-b773b730369d",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Sex=Female<br>CalculatedAge=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Female","offsetgroup":"Female","orientation":"v","showlegend":true,"x":[22.0,37.0,60.0,37.0,29.0,46.0,null,53.0,40.0,37.0,42.0,46.0,12.0,44.0,39.0,null,38.0,40.0,27.0,54.0,38.0,43.0,27.0,46.0,47.0,18.0,42.0,35.0,46.0,52.0,27.0,35.0,38.0,40.0,48.0,37.0,26.0,40.0,36.0,43.0,29.0,32.0,34.0,null,54.0,29.0,38.0,36.0,38.0,44.0,44.0,35.0,58.0,50.0,41.0,33.0,11.0,42.0,39.0,38.0,39.0,49.0,27.0,48.0,null,7.0,60.0,36.0,58.0,40.0,56.0,16.0,30.0,null,41.0,null,38.0,32.0,65.0,35.0,50.0,57.0,28.0,32.0,47.0,36.0,29.0,39.0,67.0,37.0,null,57.0,37.0,null,38.0,31.0,47.0,12.0,38.0,53.0,34.0,29.0,null,46.0,45.0,29.0,69.0,53.0,38.0,39.0,15.0,10.0,64.0,38.0,56.0,null,7.0,37.0,10.0,36.0,62.0,36.0,50.0,34.0,56.0,null,46.0,39.0,43.0,36.0,null,32.0,48.0,30.0,47.0,41.0,null,47.0,36.0,46.0,48.0,65.0,null,66.0,46.0,32.0,38.0,42.0,47.0,null,36.0,46.0,45.0,56.0,51.0,41.0,68.0,32.0,40.0,34.0,40.0,46.0,56.0,null,null,32.0,13.0,39.0,54.0,35.0,33.0,37.0,44.0,31.0,28.0,null,59.0,null,39.0,43.0,42.0,40.0,9.0,32.0,null,null,29.0,33.0,42.0,63.0,39.0,64.0,6.0,45.0,31.0,24.0,8.0,37.0,19.0,null,47.0,49.0,50.0,34.0,52.0,48.0,35.0,40.0,25.0,33.0,34.0,40.0,35.0,58.0,44.0,52.0,34.0,43.0,null,48.0,46.0,26.0,28.0,null,32.0,39.0,47.0,null,30.0,51.0,54.0,45.0,41.0,37.0,58.0,26.0,38.0,40.0,null,43.0,41.0,45.0,null,42.0,31.0,37.0,16.0,38.0,47.0,78.0,38.0,35.0,26.0,36.0,30.0,53.0,37.0,19.0,45.0,13.0,39.0,24.0,53.0,37.0,51.0,51.0,10.0,36.0,61.0,65.0,34.0,null,37.0,60.0,36.0,null,39.0,28.0,9.0,43.0,40.0,40.0,36.0,null,45.0,null,null,29.0,68.0,10.0,31.0,57.0,26.0,44.0,30.0,41.0,67.0,28.0,37.0,44.0,35.0,58.0,37.0,49.0,34.0,33.0,35.0,null,37.0,null,34.0,65.0,39.0,38.0,48.0,83.0,42.0,43.0,34.0,39.0,44.0,44.0,37.0,41.0,44.0,47.0,36.0,26.0,32.0,36.0,48.0,39.0,40.0,48.0,32.0,46.0,33.0,41.0,null,38.0,38.0,null,44.0,null,27.0,23.0,40.0,10.0,null,12.0,36.0,38.0,42.0,44.0,32.0,48.0,31.0,53.0,43.0,38.0,35.0,69.0,48.0,39.0,37.0,29.0,42.0,38.0,29.0,31.0,61.0,21.0,37.0,36.0,43.0,50.0,32.0,41.0,47.0,35.0,29.0,32.0,38.0,13.0,39.0,40.0,26.0,null,null,27.0,57.0,41.0,43.0,null,30.0,34.0,38.0,31.0,43.0,39.0,47.0,35.0,26.0,41.0,15.0,54.0,50.0,9.0,8.0,37.0,39.0,33.0,34.0,32.0,47.0,null,11.0,61.0,null,47.0,45.0,47.0,36.0,38.0,46.0,37.0,41.0,28.0,44.0,55.0,26.0,37.0,16.0,42.0,31.0,36.0,54.0,44.0,55.0,31.0,43.0,50.0,34.0,37.0,46.0,28.0,42.0,40.0,39.0,32.0,40.0,38.0,14.0,48.0,29.0,44.0,40.0,40.0,49.0,61.0,54.0,20.0,37.0,36.0,43.0,37.0,43.0,45.0,44.0,57.0,35.0,52.0,42.0,38.0,66.0,null,44.0,41.0,null,50.0,37.0,27.0,null,38.0,47.0,53.0,29.0,null,38.0,null,43.0,38.0,34.0,43.0,39.0,30.0,36.0,58.0,41.0,23.0,25.0,35.0,42.0,15.0,34.0,42.0,47.0,null,44.0,69.0,40.0,37.0,34.0,59.0,62.0,47.0,29.0,37.0,48.0,21.0,30.0,10.0,48.0,36.0,null,38.0,51.0,56.0,54.0,41.0,37.0,37.0,38.0,41.0,42.0,45.0,45.0,43.0,37.0,58.0,36.0,31.0,28.0,null,40.0,27.0,null,68.0,34.0,47.0,68.0,43.0,64.0,47.0,41.0,37.0,31.0,34.0,66.0,41.0,36.0,34.0,52.0,null,36.0,29.0,45.0,36.0,35.0,8.0,44.0,48.0,28.0,45.0,38.0,33.0,44.0,28.0,null,47.0,41.0,56.0,62.0,13.0,43.0,37.0,60.0,80.0,41.0,48.0,25.0,40.0,41.0,42.0,48.0,47.0,24.0,41.0,72.0,26.0,50.0,33.0,65.0,34.0,46.0,31.0,34.0,40.0,38.0,null,44.0,29.0,48.0,43.0,39.0,23.0,51.0,30.0,40.0,63.0,42.0,40.0,33.0,38.0,42.0,36.0,31.0,59.0,null,52.0,73.0,43.0,34.0,47.0,46.0,36.0,50.0 ...

# %% [markdown]
# ### Age Grouping and Distribution Plot
# ##### After sorting out the age, we can now group the ages to different groups to help the analysis. We can use the cut function in pandas to cut the distribution of the age groups. We can then plot the age distribution, and also visualize it better with the plotly library

# %%
#Importing plotly library for better visualization
bins = [0,5,10,15,20,25,30,35,40,45,50,55,60,65,200]
age_labels = ['0-5','5-10','10-15','15-20','20-25','25-30','30-35', '35-40', '40-45', '45-50', '50-55', '55-60', '60-65', '65+']
data['AgeGroup'] = pd.cut(data['CalculatedAge'], bins=bins, labels=age_labels, right=False)

#re-arrange age group in order of numerical age value.
age_group = data['AgeGroup'].value_counts()

age_group_counts = []
for label in age_labels:
    age_group_counts.append(age_group[label])
    
# Create an interactive bar chart using Plotly
fig = go.Figure(data=[go.Bar(x=age_labels, y=age_group_counts, marker_color='red')])
fig.update_layout(
    title="Age Group Distribution",
    xaxis_title="Age groups",
    yaxis_title="No of clients",
    width=800,  # Set the width of the figure
    height=500  # Set the height of the figure
)

# Display the interactive plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="30570e9b-62c6-4622-8562-d18c9c8201b8" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30570e9b-62c6-4622-8562-d18c9c8201b8")) {                    Plotly.newPlot(                        "30570e9b-62c6-4622-8562-d18c9c8201b8",                        [{"marker":{"color":"red"},"x":["0-5","5-10","10-15","15-20","20-25","25-30","30-35","35-40","40-45","45-50","50-55","55-60","60-65","65+"],"y":[7,815,911,504,456,1242,2728,4358,4118,3371,2421,1614,932,1008],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"s ...

# %% [markdown]
# ###
